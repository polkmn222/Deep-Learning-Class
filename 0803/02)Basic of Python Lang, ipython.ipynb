# %% [markdown]
# 파이썬을 기초보다 더욱 공부하길 원하느 분들을 위해서는 아래의 3권의 책을 권한다.

# %% [markdown]
#     * [Python Cook-Book Third Edition] - David Beasley, Brian K. Jones
#
#     * [Fluent Python] - Luciano Ramalho
#
#     * [Effective Python] - Brett Slatkin

# %% [markdown]
# 국내 정발판 Version (국어version)
#
#     * [파이썬 쿡북] - (데이비드 비즐리, 브라이언 K 존, 인피니티북스)
#
#     * [Fluent Python] - (루시아누 하말류, 한빛미디어)
#
#     * [Effective Python] - (브렛 스래킨, 길벗)

# %% [markdown]
# ## IPython 셀 실행하기
#
# IPython은 일반 파이썬 인터피리터를 실행시키듯이 ipython 명령어를 입력하여 실행시킬 수 있다

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 위의 그림을 살펴보면 Python의 version과 copyright등을 확인할 수 있으며 해당 Line에 직접 python 코드를 입력하고 Enter키를 통해 실행시킬 수 있다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 첫 두 줄의 파이썬 코드의 의미를 Basic Python을 본 강사에게 들었다면 이해할 수 있을 것이다. 두 번째 줄에서 data라는 이름의 변수를 생성하고 새로 생성한 파이썬 dict를 참조하도록 했다. 마지막 줄은 data 변수의 값을 출력한다.

# %% [markdown]
# 대부분의 파이썬 객체는 print를 이용한 보통의 출력 결과와는 달리 좀 더 읽기 편하거나 ***보기 좋은 형태로 출력*** 된다. 위의 예제를 prompt로 살펴보면 다소 불편하다

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 또한 IPython은 일부 코드(약간 개선된 복사/붙여넣기 기능을 통해) 아니면 전체 파이썬 스크립트를 쉽게 실행할 수 있는 기능을 제공한다. 또한 IPython시스템을 활용하여 구현되는 Jupyter Notebook이 많은 분량의 코드를 손쉽게 다룰 수 있도록 구현된다.

# %% [markdown]
# ## 주피터 노트북 실행하기
#
# 주피터 프로젝트( 01)번 ipynb에서 설명했었던 )의 주요 구성요소 중 하나인 ***Notebook***은 코드, 텍스트, 데이터 시각화를 비롯한 다른 출력을 대화형으로 구성할 수 있는 대화형 문서 형식이다.
#
# Jupyter Notebook은 어떠한 프로개르밍 언어로도 작성 가능한 Jupyter Interactive Computing Protocol(주피터 대화형 컴퓨팅 프로토콜)의 구현체인 커널(Kernel)과 상호작용한다.

# %% [markdown]
# Python Jupyter Kernel은 IPython System을 활용하여 동작한다. Jupyter를 실행하려면 Terminal에 jupyter notebook을 입력하면 된다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 대부분의 플랫폼에서는 -- no - browser 옵션을 지정하지 않으면 자동으로 기본 웹 브라우저를 실행한다. 혹시 내가 실수로 웹 브라우저를 종료하였다면,
#
# 위의 화면에서의 http://localhost : 8888/ xxxxxx 로 시작하는 주소를 복사(copy)하여 접속하거나, http://127.0.0.1:8888/ xxxx로 시작하는 주소를 복사하여 실행할 수 있다.

# %% [markdown]
# 위와 같이 실행하면 주피터 노트북의 랜딩 페이지는 아래와 같이 나오게 된다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 새로운 주피터 노트북을 생성하려면 위의 화면에서 New 버튼을 클릭하고 'Python3' 옵션을 선택하여 아래와 같은 주피터 노트북을 만들 수 있다.

# %% [markdown]
# Notebook File의 저장을 원하면 노트북의  File 메뉴에서 Save and Checkpoint 클릭하면 된다.
#
# Jupyter Notebook은 IPython과는 완전히 다른 경험을 주기는 하지만 Python의 경우 양쪽 환경 모두에서 사용할 수 있다.

# %% [markdown]
# ## 탭 자동완성

# %% [markdown]
# IPython은 표준 파이썬 인터프리터와의 가장 큰 차이는 ***탭을 통한 자동완성 기능***으로, 대부분의 통합 개발 환경이나 대화형 데이터 분석 환경에 구현되어 있는 기능이다. Shell에서 입력하는 동안 Tab을 활용하면 Namespace에서 그 시점까지 입력한 내용과 맞는 변수(객체, 함수 등)를 자동으로 찾아준다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Jupyter Notebook과 IPython 5.0 이상 버전에서는 자동완성목록이 drop-down 형식으로 나타납니다.

# %% [markdown]
# ## 자기관찰(Introspection)

# %% [markdown]
# 변수 이름 앞이나 뒤에 ?기호를 붙이면 그 객체에 대한 일반 정보를 출력한다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 위와 같은 docstring을 출력한다
b = [1,2,3]

b?

# %% [markdown]
# 만약 객체가 함수이거나 인스턴스 메서드라면 정의되어 있는 문서docstring을 출력해준다.
#
# 아래의 함수를 작성하여 저장했다고 해보자.

# %%
def add_numbers(a, b):
    """
    Add two numbers together

    Returns
    -------
    the_sum : type of arguments
    """
    return a + b

# %%
## ?기호를 통해 문서를 출력하면?
# ?add_numbers

# %% [markdown]
# 만약 와일드카드(*)기호를 사용한다면 사용한 문자와 일치하는 모든 이름을 보여준다. 만약에 Numpy의 최상단 네임스페이스 안에 load를 폿함하는 모든 함수 목록을 가져올 수 있다.

# %%
import numpy as np
# ?np.*load*

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 주피터 노트북에서는 스크립트 파일을 코드 셀로 불러오는 %load 매직함수를 사용할 수도 있다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 실행 중인 코드 중지하기

# %% [markdown]
# %run을 통해 스크립트가 실행되고 있거나 오랜 실행 시간이 필요한 코드가 실행되고 있는 중간에 Ctrl-C를 누르면 KeyboardInterrupt 예외를 발생시킨다. 이 예외는 몇몇 특수경우를 제외하고 거의 모든 python program을 즉시 멈추도록 한다.

# %% [markdown]
# * 참고 :: 실행 중인 Python code가 Complie된 Extension Module에서 호출된 경우에는 Ctrl + C를 눌러도 Program Intterupt가 즉각적으로 일어나지 않는데, 이러한 경우에는 프로그램의 제어권이 Python InterPreter로 돌아올 때까지 기다리거나, 심각한 경우 OS의 작업관리자 메뉴를 활용하여 Python Process를 강제 종료해야 한다.

# %% [markdown]
# ### 매직 명령어

# %% [markdown]
# IPython은 파이썬 자체에는 존재하지 않는 '매직'명령어라고 하는 여러가지 특수한 명령어를 포함하고 있다. 이 매직 명령어는 일반적인 작업이나 IPython 시스템의 동작을 쉽게 제어할 수 있도록 설계된 특수 명령어이다.

# %% [markdown]
# 매직 명령어는 앞에 %기호를 붙이는 형식인데, 예를 들어 IPython에서 행렬 곱셈 같은 코드가 실행된 시간을 측정하고 싶을 때 %timeit 매직 함수를 이용해서 값을 얻어얼 수 있다.

# %%
# 난수 생성
import numpy as np
a = np.random.randn(100, 100)

# %timeit np.dot(a,a)

# %% [markdown]
# 매직 명령어는 IPython 시스템 안에서 실행되는 명령행 프로그램으로 볼 수 있는데, 많은 매직 명령어는 추가 옵션을 필요로 하며 ?를 활용하여 전체 옵션을 살펴볼 수 있다.

# %%
# %debug?

# %% [markdown]
# 매직함수와 같은 이름의 변수가 선언되어 있지 않다면 기본적으로 % 기호 없이도 매직함수를 사용할 수 있다. 이를
# ***오토매직(automagic)***이라 하는데
# %automagic을 활용하여 이 기능을 켜거나 끌 수 있다.

# %%
# %pwd

# %%
pwd

# %% [markdown]
# |명령어|설명|
# |------|------|
# |%quickref|IPython의 빠른 도움말 표시|
# |%magic|모든 매직함수에 대한 상세 도움말 출력|
# |%debug|최근 예외 트레이스백의 하단에서 대화형 디버거로 진입|
# |%hist|명령어 입력(그리고 선택적 출력) 히스토리 출력|
# |%pdb|예외가 발생하면 자동으로 디버거로 진입|
# |%paste|클립보드에서 들여쓰기 된 채로 파이썬 코드 가져오기|
# |%cpaste|실행할 파이썬 콛3ㅡ를 수동으로 붙여 넣을 수 있는 프롬프트 표시|
# |%reset|대화형 네임스페이스에 정의된 모든 변수와 이름을 삭제|
# |%page OBJECT|객체를 pager를 통해 보기 좋게 출력|
# |%run script.py|IPython내에서 파이썬 스크립트 실행|
# |%prun statement|cProfile을 이용하여 statement를 실행하고 프로파일 결과를 출력|
# |%time statement|statement의 단일 실행 시간을 출력|
# |%timeit statement|statement를 여러 차례 실행한 후 평균 실행 시간을 출력. 매우 짧은 시간 안에 끝나는 코드의 시간을 측정할 때 유용|
# |%who, %who_ls, %whos|대화형 네임스페이스 내에 정의된 변수를 다양한 방법으로 표시|
# |%xdel variable|variable을 삭제하고 IPython 내부적으로 해당 객체에 대한 모든 참조를 제거|

# %% [markdown]
# ### matplotlib 통합

# %% [markdown]
# IPython이 분석 컴퓨팅 환경에서 널리 사용되고 있는 이유는 데이터 시각화를 위한 matplotlib이나 다른 사용자 인터페이스 라이브러리와 잘 통합되어 있기 때문이다. matplotlib은 향후 더 보강하여 기술토록 하겠다.
#
# %matplotlib 매직함수는 IPython shell이나 Jupyter notebook과 matplotlib과의 Integration을 설정한다. 이 기능을 실행하지 않으면 Notebook의 경우 Graph Visualization error이거나 Shell의 경우 Session의 제어권을 빼앗기게 되므로 매우 중요하다.

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
plt.plot(np.random.randn(50).cumsum())

# %%
# end of file
